# %%
from selenium import webdriver
from random import*
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.by import By
from datetime import datetime

driver=webdriver.Chrome("C:\\webdriver\\chromedriver.exe")
driver.get("https://www.techlistic.com/p/selenium-practice-form.html")


driver.find_element_by_name("firstname").send_keys("Abhishek")
driver.find_element_by_name("lastname").send_keys("giri")

r1=randint(1,2)
if r1==1 :
    driver.find_element_by_id("sex-0").click()
    
elif r1==2 :
    driver.find_element_by_id("sex-1").click()
    
    
r2=randint(0,6)
if  r2==0:
    driver.find_element_by_id("exp-0").click()
elif r2==1:
    driver.find_element_by_id("exp-1").click()
elif r2==2:
    driver.find_element_by_id("exp-2").click()
elif r2==3:
    driver.find_element_by_id("exp-3").click()
elif r2==4:
    driver.find_element_by_id("exp-4").click()
elif r2==5:
    driver.find_element_by_id("exp-5").click()
elif r2==6:
    driver.find_element_by_id("exp-6").click()
    
    
x=str(datetime.date(datetime.now()))

driver.find_element_by_id("datepicker").send_keys(x)


driver.find_element_by_id("profession-0").click()
driver.find_element_by_id("profession-1").click()

driver.find_element_by_id("tool-2").click()


Select(driver.find_element_by_id("continents")).select_by_index(randint(0,6))

Select(driver.find_element_by_id("selenium_commands")).select_by_index(randint(0,4))

# driver.switch_to_frame(0)
# driver.find_element_by_id("photo").send_keys("E://WALLPAPER//anime//img2.jpg")

# driver.switch_to_default_content()

driver.find_element(By.NAME,"photo").send_keys("E://WALLPAPER//anime//img2.jpg")

driver.find_element_by_id("submit").click()
